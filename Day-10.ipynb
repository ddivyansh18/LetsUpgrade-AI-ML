# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('general_data.csv')

# %%
df.head(10)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
# 5   46        No      Travel_Rarely  Research & Development                 8
# 6   28       Yes      Travel_Rarely  Research & Development                11
# 7   29        No      Travel_Rarely  Research & Development                18
# 8   31        No      Travel_Rarely  Research & Development                 1
# 9   25        No         Non-Travel  Research & Development                 7
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %% [markdown]
# The following hypothesis can be formulated :
# 1. The average percentage of salary hike is more than 10%
# 2. The average years since last promotion is less than 2 years
# 3. The average age of employees is more than 30 years
# 4. The average distance from home is less than 5 km
# 5. The average number of companies previously worked is not equal to 2
# 6. The average stock option level is less than 2
# 7. The average years worked at company is more than 5 years
# 8. The average years with current manager is more than 3 years
# 9. The average education level is less than 3
# 10. The average total working years is less than 15
